# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('Speed_Dating_Data.csv')

# %%
data.dropna()
# Out:
# Empty DataFrame
# Columns: [iid, id, gender, idg, condtn, wave, round, position, positin1, order, partner, pid, match, int_corr, samerace, age_o, race_o, pf_o_att, pf_o_sin, pf_o_int, pf_o_fun, pf_o_amb, pf_o_sha, dec_o, attr_o, sinc_o, intel_o, fun_o, amb_o, shar_o, like_o, prob_o, met_o, age, field, field_cd, undergra, mn_sat, tuition, race, imprace, imprelig, from, zipcode, income, goal, date, go_out, career, career_c, sports, tvsports, exercise, dining, museums, art, hiking, gaming, clubbing, reading, tv, theater, movies, concerts, music, shopping, yoga, exphappy, expnum, attr1_1, sinc1_1, intel1_1, fun1_1, amb1_1, shar1_1, attr4_1, sinc4_1, intel4_1, fun4_1, amb4_1, shar4_1, attr2_1, sinc2_1, intel2_1, fun2_1, amb2_1, shar2_1, attr3_1, sinc3_1, fun3_1, intel3_1, amb3_1, attr5_1, sinc5_1, intel5_1, fun5_1, amb5_1, dec, attr, sinc, ...]
# Index: []
#
# [0 rows x 195 columns]

# %%
# df = DataFrame(data, columns = ['iid','pid','gender','match','dec_o',\
#                                 'age','age_o','samerace','int_corr','date','go_out', 'field_cd',\
#                                 'attr3_1','sinc3_1','intel3_1','fun3_1','amb3_1',\
#                                 'attr_o','sinc_o','intel_o','fun_o','amb_o','shar_o',\
#                                 'attr1_1','sinc1_1','intel1_1','fun1_1','amb1_1','shar1_1'])
#only include subjective and objective profile
df = DataFrame(data, columns = ['iid','pid','gender','match','dec_o',\
                                'age','age_o','samerace','int_corr','date','go_out', 'field_cd',\
                                'attr3_1','sinc3_1','intel3_1','fun3_1','amb3_1',\
                                'attr_o','sinc_o','intel_o','fun_o','amb_o','shar_o'])

# %%
df_m = df[df['gender']==1]#male
df_f = df[df['gender']==0]#female

# %%
df_mean_m = df_m.groupby('iid').mean()
df_mean_f = df_f.groupby('iid').mean()

# %%
df_mean_f.shape
# Out:
# (274, 22)

# %%
df_mean_m.shape
# Out:
# (274, 22)

# %%
df_mean_m.head()
# Out:
#       pid  gender  match  dec_o   age  age_o  samerace  int_corr  date  \
# iid
# 1    15.5     0.0    0.4    0.5  21.0   25.2       0.1     0.267   7.0
# 2    15.5     0.0    0.2    0.6  24.0   25.2       0.8     0.258   5.0
# 3    15.5     0.0    0.0    0.5  25.0   25.2       0.8    -0.136   3.0
# 4    15.5     0.0    0.2    0.6  23.0   25.2       0.8    -0.007   5.0
# 5    15.5     0.0    0.2    0.3  21.0   25.2       0.8    -0.079   4.0
#
#      go_out   ...    sinc3_1  intel3_1  fun3_1  amb3_1  attr_o  sinc_o  \
# iid           ...
# 1       1.0   ...        8.0       8.0     8.0     7.0     6.7     7.4
# 2       1.0   ...        5.0       8.0    10.0     3.0     7.7     7.1
# 3       1.0   ...        9.0       9.0     8.0     8.0     6.5     7.1
# 4       1.0   ...        8.0       7.0     9.0     8.0     7.0     7.1
# 5       1.0   ...        3.0      10.0     6.0     8.0     5.3     7.7
#
#      intel_o  fun_o     amb_o  shar_o
# iid
# 1        8.0    7.2  8.000000     7.1
# ...

# %%
df_mean = df.groupby('iid').mean()
df_mean.head()
# Out:
#       pid  gender  match  dec_o   age  age_o  samerace  int_corr  date  \
# iid
# 1    15.5     0.0    0.4    0.5  21.0   25.2       0.1     0.267   7.0
# 2    15.5     0.0    0.2    0.6  24.0   25.2       0.8     0.258   5.0
# 3    15.5     0.0    0.0    0.5  25.0   25.2       0.8    -0.136   3.0
# 4    15.5     0.0    0.2    0.6  23.0   25.2       0.8    -0.007   5.0
# 5    15.5     0.0    0.2    0.3  21.0   25.2       0.8    -0.079   4.0
#
#      go_out   ...    sinc3_1  intel3_1  fun3_1  amb3_1  attr_o  sinc_o  \
# iid           ...
# 1       1.0   ...        8.0       8.0     8.0     7.0     6.7     7.4
# 2       1.0   ...        5.0       8.0    10.0     3.0     7.7     7.1
# 3       1.0   ...        9.0       9.0     8.0     8.0     6.5     7.1
# 4       1.0   ...        8.0       7.0     9.0     8.0     7.0     7.1
# 5       1.0   ...        3.0      10.0     6.0     8.0     5.3     7.7
#
#      intel_o  fun_o     amb_o  shar_o
# iid
# 1        8.0    7.2  8.000000     7.1
# ...

# %%
corr = df_mean.corr()

# %%
corr_m = df_mean_m.corr()
corr_f = df_mean_f.corr()

# %%
corr
# Out:
#                pid    gender     match     dec_o       age     age_o  \
# pid       1.000000 -0.029345 -0.074695 -0.020958  0.138509  0.312168
# gender   -0.029345  1.000000  0.001802 -0.224944  0.061270 -0.149285
# match    -0.074695  0.001802  1.000000  0.525374 -0.110117 -0.122992
# dec_o    -0.020958 -0.224944  0.525374  1.000000 -0.116305  0.065995
# age       0.138509  0.061270 -0.110117 -0.116305  1.000000  0.298791
# age_o     0.312168 -0.149285 -0.122992  0.065995  0.298791  1.000000
# samerace -0.002693  0.000076 -0.017708  0.092909  0.022258  0.077912
# int_corr  0.114696 -0.001468  0.037131  0.030730  0.154769  0.086033
# date      0.006533 -0.101573 -0.205659 -0.157907  0.022022  0.075674
# go_out    0.042746  0.011891 -0.183561 -0.227766  0.107377  0.083845
# field_cd  0.147655 -0.078618 -0.080035  0.043539  0.133463  0.165647
# attr3_1   0.034201 -0.107022  0.131688  0.192764  0.055596 -0.012287
# sinc3_1   0.086126 -0.129113 -0.013600 -0.014021 -0.003265  0.061616
# ...

# %%
corr_m
# Out:
#                pid  gender     match     dec_o       age     age_o  samerace  \
# pid       1.000000     NaN -0.075804 -0.103613  0.140986  0.336755 -0.006724
# gender         NaN     NaN       NaN       NaN       NaN       NaN       NaN
# match    -0.075804     NaN  1.000000  0.460914 -0.120591 -0.121165 -0.112788
# dec_o    -0.103613     NaN  0.460914  1.000000 -0.134450  0.035338  0.032690
# age       0.140986     NaN -0.120591 -0.134450  1.000000  0.318602 -0.001734
# age_o     0.336755     NaN -0.121165  0.035338  0.318602  1.000000  0.067535
# samerace -0.006724     NaN -0.112788  0.032690 -0.001734  0.067535  1.000000
# int_corr  0.137347     NaN  0.074694  0.089298  0.193911  0.070755 -0.020551
# date      0.005737     NaN -0.130004 -0.097267  0.135628  0.088872 -0.059164
# go_out    0.061176     NaN -0.106460 -0.146864  0.160926  0.101797 -0.218353
# field_cd  0.219473     NaN -0.089379  0.027319  0.051398  0.101267 -0.070975
# ...

# %%
corr_f
# Out:
#                pid  gender     match     dec_o       age     age_o  samerace  \
# pid       1.000000     NaN -0.075804 -0.103613  0.140986  0.336755 -0.006724
# gender         NaN     NaN       NaN       NaN       NaN       NaN       NaN
# match    -0.075804     NaN  1.000000  0.460914 -0.120591 -0.121165 -0.112788
# dec_o    -0.103613     NaN  0.460914  1.000000 -0.134450  0.035338  0.032690
# age       0.140986     NaN -0.120591 -0.134450  1.000000  0.318602 -0.001734
# age_o     0.336755     NaN -0.121165  0.035338  0.318602  1.000000  0.067535
# samerace -0.006724     NaN -0.112788  0.032690 -0.001734  0.067535  1.000000
# int_corr  0.137347     NaN  0.074694  0.089298  0.193911  0.070755 -0.020551
# date      0.005737     NaN -0.130004 -0.097267  0.135628  0.088872 -0.059164
# go_out    0.061176     NaN -0.106460 -0.146864  0.160926  0.101797 -0.218353
# field_cd  0.219473     NaN -0.089379  0.027319  0.051398  0.101267 -0.070975
# ...

# %%
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask,cmap=cmap, square=True, linewidths=.5, cbar_kws={"shrink": .5})
f.savefig("corr.png")
